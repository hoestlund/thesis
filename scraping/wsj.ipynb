# %% [markdown]
# ## Wall Street Journal
#
# Intesting layout. Breakdown by year, month, day
# https://www.wsj.com/news/archive/years
#
# For each day of news there is a drop down bar for the page numbers. When the amount of articles is exceeded then there are just blank results coming up on the page https://www.wsj.com/news/archive/2020/01/31?page=5
